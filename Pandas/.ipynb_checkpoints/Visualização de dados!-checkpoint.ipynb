# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#plt.style.use('ggplot')
#plt.style.use('bnh')
plt.style.use('dark_background')

# %%
df1 = pd.read_csv('df1',index_col=0)
df2 = pd.read_csv('df2');
df3 = pd.read_csv('df3');

# %%
df1['A'].plot.hist()

# %%
df1['A'].plot.hist(bins=100)

# %%
#Plota area
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar(alpha=0.9, stacked=True)

# %%
df2.plot.bar(alpha=0.9)

# %%
df1.plot.line()

# %%
df1.plot.line(x = df1.index, y='B', figsize = (16,5), lw = 1)

# %%
df1.plot.scatter(x='A', y='B');

# %%
df1.plot.scatter(x='A', y='B', c='D', cmap ='inferno',figsize = (16,5)); #parametro c define como será a cor nas bolinhas

# %%
df1.plot.scatter(x='A', y='B', s=df1['D']*20, figsize = (16,5)); #parametro S define como será o tamanho das bolinhas
# Out:
# C:\Users\Usuario\Anaconda3\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box(figsize = (16,5))

# %%
dfAleatorio = pd.DataFrame(np.random.rand(1000,2), columns= ['colun1', 'colun2'])
dfAleatorio.plot.hexbin(x='colun1',y='colun2', figsize = (16,5), gridsize=20)

# %%
df2['a'].plot.kde(figsize = (16,5))

# %%
df2.plot.kde(figsize = (16,5))
