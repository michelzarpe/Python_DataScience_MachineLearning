# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline #VISUALIZAR OS PLOTS NA PROPRIA LINHA
# Out:
# UsageError: unrecognized arguments: #VISUALIZAR OS PLOTS NA PROPRIA LINHA

# %%
espaceVetorial_x = np.linspace(0,5,11);
espaceVetorial_x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
espaceVetorial_y = espaceVetorial_x * espaceVetorial_x

# %%
espaceVetorial_y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#Funcional
plt.plot(espaceVetorial_x,espaceVetorial_y,'r--');
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.title('Titulo')
# Out:
# Text(0.5,1,'Titulo')

# %%
plt.subplot(1,2,1)
plt.plot(espaceVetorial_x,espaceVetorial_y,'r--');
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.title('Grafico 1')
plt.subplot(1,2,2)
plt.plot(espaceVetorial_x,espaceVetorial_y,'g*-');
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.title('Grafico 2')
# Out:
# Text(0.5,1,'Grafico 2')

# %%
#orientado objetos
fig = plt.figure(); #criado uma caixa vazia
axes1 = fig.add_axes([0.1,0.1,0.3,0.3]);
axes2 = fig.add_axes([0.5,0.1,0.3,0.3]);
axes1.plot(espaceVetorial_x,espaceVetorial_y,'g*-')
axes1.set_xlabel('Eixo x')
axes1.set_ylabel('Eixo y')
axes1.set_title('Grafico 1')
axes1.plot(espaceVetorial_y,espaceVetorial_x,'b--')
axes2.plot(espaceVetorial_y,espaceVetorial_x,'r--')

# %%
fig, eixo = plt.subplots() #cria a figura e o eixo junto
eixo.plot(espaceVetorial_y,espaceVetorial_x,'b--')
eixo.plot(espaceVetorial_x,espaceVetorial_y,'r-.')
eixo.plot(espaceVetorial_x,espaceVetorial_x**3,'g-*')
eixo.plot(espaceVetorial_x,espaceVetorial_x**4,'y')
eixo.set_xlabel('X')
eixo.set_ylabel('Y')
eixo.set_title('TITULO')
# Out:
# Text(0.5,1,'TITULO')

# %%
fig1, ax1 = plt.subplots(1,2) #cria a figura e o eixo junto
c=0
for axe in ax1:
    c=c+1
    axe.plot(espaceVetorial_x,espaceVetorial_y,'r-.')
    titulo = 'Titulo'+str(c)
    axe.set_title(titulo)

# %%
fig, ax = plt.subplots(1,2) #cria a figura e o eixo junto
ax[0].plot(espaceVetorial_x,espaceVetorial_y,'r-.')
titulo = 'Titulo1'
ax[0].set_title(titulo)

ax[1].plot(espaceVetorial_x,espaceVetorial_y,'b-*')
titulo = 'Titulo1'
ax[1].set_title(titulo)
# Out:
# Text(0.5,1,'Titulo1')

# %%
#fig, ax = plt.subplots(2,5, figsize=(50,30)) #figsize coloca tamanho na figura
fig, ax = plt.subplots(2,5) #cria a figura e o eixo junto
ax[0,0].plot(espaceVetorial_x,espaceVetorial_x,'r-.')
titulo = 'Titulo1'
ax[0,0].set_title(titulo)

ax[0,1].plot(espaceVetorial_y,espaceVetorial_y,'b-*')
titulo = 'Titulo1'
ax[0,1].set_title(titulo)
plt.tight_layout()

ax[0,2].plot(espaceVetorial_x,espaceVetorial_y,'b-*')
titulo = 'Titulo1'
ax[0,2].set_title(titulo)
plt.tight_layout()

ax[0,3].plot(espaceVetorial_y,espaceVetorial_x,'b-*')
titulo = 'Titulo1'
ax[0,3].set_title(titulo)
plt.tight_layout()

ax[0,4].plot(espaceVetorial_x,espaceVetorial_x**3,'b-*')
titulo = 'Titulo1'
ax[0,4].set_title(titulo)
plt.tight_layout()

ax[1,0].plot(espaceVetorial_x,espaceVetorial_x**4,'r-.')
titulo = 'Titulo1'
ax[1,0].set_title(titulo)

ax[1,1].plot(espaceVetorial_x,espaceVetorial_x**5,'b-*')
titulo = 'Titulo1'
ax[1,1].set_title(titulo)
plt.tight_layout()

ax[1,2].plot(espaceVetorial_x,espaceVetorial_x**7,'b-*')
titulo = 'Titulo1'
ax[1,2].set_title(titulo)
plt.tight_layout()

ax[1,3].plot(espaceVetorial_x,espaceVetorial_x**8,'b-*')
titulo = 'Titulo1'
ax[1,3].set_title(titulo)
plt.tight_layout()

ax[1,4].plot(espaceVetorial_x,espaceVetorial_x**9,'b-*')
titulo = 'Titulo1'
ax[1,4].set_title(titulo)
plt.tight_layout()
fig.savefig("imagem.png")

# %%
fig, ax = plt.subplots(figsize=(12,10)) #figsize coloca tamanho na figura
ax.plot(espaceVetorial_x,espaceVetorial_x-1,'r',label='x,x-1')
ax.plot(espaceVetorial_x*-1,(espaceVetorial_x*-1)+1,'c',label='x*-1,(x*-1)+1')
ax.plot(espaceVetorial_x,espaceVetorial_y,'g-*',label='x,y')
ax.plot(espaceVetorial_x,espaceVetorial_y*-1,'y*',label='x,y*-1')
ax.plot(espaceVetorial_y,espaceVetorial_y,'b',label='y,y',linewidth=5, alpha=0.5)
ax.set_title('Titulo1')
ax.set_xlabel('orizontal')
ax.set_ylabel('vertical')
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(12,10))

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0)) 

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

ax.plot(espaceVetorial_x,espaceVetorial_x-1,'r',label='x,x-1')
ax.plot(espaceVetorial_x*-1,(espaceVetorial_x*-1)+1,'c',label='x*-1,(x*-1)+1')
ax.plot(espaceVetorial_x,espaceVetorial_y,'g-*',label='x,y')
ax.plot(espaceVetorial_x,espaceVetorial_y*-1,'y*',label='x,y*-1')
ax.plot(espaceVetorial_y,espaceVetorial_y,'b',label='y,y',linewidth=5, alpha=0.5)
ax.set_title('Titulo1')
ax.legend()

# %%
alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)

X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

fig = plt.figure(figsize=(14,6))

# `ax` é uma instância de eixo com reconhecimento 3D devido ao argumento de palavra-chave projection = '3d' para add_subplot
ax = fig.add_subplot(1, 2, 1, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# surface_plot com classificação de cores e barra de cores
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\projections\__init__.py in get_projection_class(projection)
#      62     try:
# ---> 63         return projection_registry.get_projection_class(projection)
#      64     except KeyError:
#
# ~\Anaconda3\lib\site-packages\matplotlib\projections\__init__.py in get_projection_class(self, name)
#      28         """
# ---> 29         return self._all_projection_types[name]
#      30
#
# KeyError: '3d'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-94064637a70d> in <module>()
#      14
#      15 # `ax` é uma instância de eixo com reconhecimento 3D devido ao argumento de palavra-chave projection = '3d' para add_subplot
# ...

# %% [markdown]
# **Plots Matriciais**

# %%
flights = sns.load_dataset('flights')
tips = sns.load_dataset('tips')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d5da20bfa218> in <module>()
# ----> 1 fights = sns.load_dataset('flights')
#       2 tips = sns.load_dataset('tips')
#
# NameError: name 'sns' is not defined
